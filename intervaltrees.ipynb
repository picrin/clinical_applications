# %%
from intervaltree import Interval, IntervalTree
import re

# %%
def unquote(s):
    if len(s) >= 2 and s[0] == '"' and s[-1] == '"':
        return s[1:-1]
    return s

# %%
probeset_full = "probesets/probesets_correct_coords.csv"

genecode_file = "annotations/gencode.v26lift37.annotation.gtf"

result_file = "probesets/annotated_probesets.csv"
allowed_chr = "^chr[0-9]?[0-9]?[XYM]?[+-]$"

# %%
def read_intervaltrees():
    headers = {}
    intervaltrees = {}
    with open(probeset_full) as f:
        for i, line in enumerate(f):
            line = line.rstrip().split()
            if not headers:
                headers = {key: value for value, key in enumerate(line)}
            else:
                probeset, chromosome, left, right, strand = [line[headers[i]] for i in ["probeset_id", "chrom", "genocode_left", "genecode_right", "strand"]]
                key = chromosome + strand
                tree = intervaltrees.setdefault(key, IntervalTree())
                try:
                    left = int(left)
                    right = int(right)
                    not_zero = left != 0 and right != 0
                    wrong_order = left >= right
                    store = not_zero
                except ValueError:
                    store = False
                if store:
                    if wrong_order:
                        raise(ValueError("must not be equal {} {}!".format(left, right)))
                    tree[left:right] = probeset
    return intervaltrees

# %%
intervaltrees = read_intervaltrees()

# %%
for i in intervaltrees["chr6+"].search(168072610, 168072791, strict=True):
    print(i.data)
# Out:
# 2936520
# 2936520
# 2936520
# 2936520

# %%
possibilities = set()

# %%
#filter_probes = 
def filter_probes(intervaltrees, genecode_file):
    filtered_probesets = {}
    with open(genecode_file) as geneList:
        currentGeneID = None
        currentGenePieces = []
        currentChromosome = None
        leftGene = 0
        rightGene = 0
        for i, line in enumerate(geneList):
            if line and line[0] == "#":
                continue

            line = line.rstrip().split("\t")
            chromo, source, typ, left, right, _, strand, _, meta = line
            left = int(left)
            right = int(right)
            meta = re.split(";[ ]?", meta)

            processed_meta = {}
            for m in meta[:-1]:
                k, v = m.split()
                processed_meta[k] = unquote(v)

            transcript_type =  processed_meta.get("transcript_type", "")
            gene_type = processed_meta.get("gene_type", "")
            
            possibilities.add((transcript_type, gene_type, typ))

            protein_coding = transcript_type == "protein_coding" or gene_type == "protein_coding"
            is_coding_or_UTR = typ in ["CDS", "UTR"]
            key = chromo + strand
            if protein_coding and is_coding_or_UTR and re.match(allowed_chr, key):
                gene_name = processed_meta["gene_name"]
                for j in intervaltrees[key].search(left, right, strict=True):
                    filtered_probesets[j.data] = gene_name
    return filtered_probesets

# %%
result = filter_probes(intervaltrees, genecode_file)

# %%
def write_strict_annotation(filename_in, probe_to_genename, filename_out):
    headers = {}
    with open(filename_out, "w") as f_out:
        print("gene_name", "probeset_id", "seq5to3plus", "chrom", "strand", "genocode_left", "genecode_right", "x", "y", sep="\t", file=f_out)
        with open(filename_in) as f:
            for i, line in enumerate(f):
                line = line.rstrip().split()
                if not headers:
                    headers = {key: value for value, key in enumerate(line)}
                else:
                    probeset_id, seq5to3plus, chrom, genocode_left, genecode_right, strand, x, y = [line[headers[i]] for i in ["probeset_id", "seq5to3plus", "chrom", "genocode_left", "genecode_right", "strand", "x", "y"]]
                    if probeset_id in probe_to_genename:
                        print(probe_to_genename[probeset_id], probeset_id, seq5to3plus, chrom, strand, genocode_left, genecode_right, x, y, sep="\t", file=f_out)

# %%
write_strict_annotation(probeset_full, result, result_file)

# %%
possibilities
# Out:
# {('', '3prime_overlapping_ncRNA', 'gene'),
#  ('', 'IG_C_gene', 'gene'),
#  ('', 'IG_C_pseudogene', 'gene'),
#  ('', 'IG_D_gene', 'gene'),
#  ('', 'IG_J_gene', 'gene'),
#  ('', 'IG_J_pseudogene', 'gene'),
#  ('', 'IG_V_gene', 'gene'),
#  ('', 'IG_V_pseudogene', 'gene'),
#  ('', 'IG_pseudogene', 'gene'),
#  ('', 'Mt_rRNA', 'gene'),
#  ('', 'Mt_tRNA', 'gene'),
#  ('', 'TEC', 'gene'),
#  ('', 'TR_C_gene', 'gene'),
#  ('', 'TR_D_gene', 'gene'),
#  ('', 'TR_J_gene', 'gene'),
#  ('', 'TR_J_pseudogene', 'gene'),
#  ('', 'TR_V_gene', 'gene'),
#  ('', 'TR_V_pseudogene', 'gene'),
#  ('', 'antisense', 'gene'),
#  ('', 'bidirectional_promoter_lncRNA', 'gene'),
#  ('', 'lincRNA', 'gene'),
#  ('', 'macro_lncRNA', 'gene'),
#  ('', 'miRNA', 'gene'),
#  ('', 'misc_RNA', 'gene'),
#  ('', 'non_coding', 'gene'),
#  ('', 'polymorphic_pseudogene', 'gene'),
#  ('', 'processed_pseudogene', 'gene'),
#  ('', 'processed_transcript', 'gene'),
#  ('', 'protein_coding', 'gene'),
#  ('', 'pseudogene', 'gene'),
#  ('', 'rRNA', 'gene'),
#  ('', 'scRNA', 'gene'),
#  ('', 'sense_intronic', 'gene'),
#  ('', 'sense_overlapping', 'gene'),
#  ('', 'snRNA', 'gene'),
#  ('', 'snoRNA', 'gene'),
#  ('', 'transcribed_processed_pseudogene', 'gene'),
#  ('', 'transcribed_unitary_pseudogene', 'gene'),
#  ('', 'transcribed_unprocessed_pseudogene', 'gene'),
#  ('', 'unitary_pseudogene', 'gene'),
#  ('', 'unprocessed_pseudogene', 'gene'),
#  ('', 'vaultRNA', 'gene'),
#  ('3prime_overlapping_ncRNA', '3prime_overlapping_ncRNA', 'exon'),
#  ('3prime_overlapping_ncRNA', '3prime_overlapping_ncRNA', 'transcript'),
#  ('3prime_overlapping_ncRNA', 'processed_transcript', 'exon'),
#  ('3prime_overlapping_ncRNA', 'processed_transcript', 'transcript'),
#  ('IG_C_gene', 'IG_C_gene', 'CDS'),
#  ('IG_C_gene', 'IG_C_gene', 'UTR'),
#  ('IG_C_gene', 'IG_C_gene', 'exon'),
#  ('IG_C_gene', 'IG_C_gene', 'stop_codon'),
#  ('IG_C_gene', 'IG_C_gene', 'transcript'),
#  ('IG_C_pseudogene', 'IG_C_pseudogene', 'exon'),
#  ('IG_C_pseudogene', 'IG_C_pseudogene', 'transcript'),
#  ('IG_D_gene', 'IG_D_gene', 'CDS'),
#  ('IG_D_gene', 'IG_D_gene', 'UTR'),
#  ('IG_D_gene', 'IG_D_gene', 'exon'),
#  ('IG_D_gene', 'IG_D_gene', 'stop_codon'),
#  ('IG_D_gene', 'IG_D_gene', 'transcript'),
#  ('IG_J_gene', 'IG_J_gene', 'CDS'),
#  ('IG_J_gene', 'IG_J_gene', 'UTR'),
#  ('IG_J_gene', 'IG_J_gene', 'exon'),
#  ('IG_J_gene', 'IG_J_gene', 'start_codon'),
#  ('IG_J_gene', 'IG_J_gene', 'transcript'),
#  ('IG_J_pseudogene', 'IG_J_pseudogene', 'exon'),
#  ('IG_J_pseudogene', 'IG_J_pseudogene', 'transcript'),
#  ('IG_V_gene', 'IG_V_gene', 'CDS'),
#  ('IG_V_gene', 'IG_V_gene', 'UTR'),
#  ('IG_V_gene', 'IG_V_gene', 'exon'),
#  ('IG_V_gene', 'IG_V_gene', 'start_codon'),
#  ('IG_V_gene', 'IG_V_gene', 'stop_codon'),
#  ('IG_V_gene', 'IG_V_gene', 'transcript'),
#  ('IG_V_pseudogene', 'IG_V_pseudogene', 'exon'),
#  ('IG_V_pseudogene', 'IG_V_pseudogene', 'transcript'),
#  ('IG_pseudogene', 'IG_pseudogene', 'exon'),
#  ('IG_pseudogene', 'IG_pseudogene', 'transcript'),
#  ('Mt_rRNA', 'Mt_rRNA', 'exon'),
#  ('Mt_rRNA', 'Mt_rRNA', 'transcript'),
#  ('Mt_tRNA', 'Mt_tRNA', 'exon'),
#  ('Mt_tRNA', 'Mt_tRNA', 'transcript'),
#  ('TEC', 'TEC', 'exon'),
#  ('TEC', 'TEC', 'transcript'),
#  ('TEC', 'processed_transcript', 'exon'),
#  ('TEC', 'processed_transcript', 'transcript'),
#  ('TEC', 'protein_coding', 'exon'),
#  ('TEC', 'protein_coding', 'transcript'),
#  ('TEC', 'transcribed_processed_pseudogene', 'exon'),
#  ('TEC', 'transcribed_processed_pseudogene', 'transcript'),
#  ('TEC', 'transcribed_unprocessed_pseudogene', 'exon'),
#  ('TEC', 'transcribed_unprocessed_pseudogene', 'transcript'),
#  ('TR_C_gene', 'TR_C_gene', 'CDS'),
#  ('TR_C_gene', 'TR_C_gene', 'UTR'),
#  ('TR_C_gene', 'TR_C_gene', 'exon'),
#  ('TR_C_gene', 'TR_C_gene', 'stop_codon'),
#  ('TR_C_gene', 'TR_C_gene', 'transcript'),
#  ('TR_D_gene', 'TR_D_gene', 'CDS'),
#  ('TR_D_gene', 'TR_D_gene', 'exon'),
#  ('TR_D_gene', 'TR_D_gene', 'transcript'),
#  ('TR_J_gene', 'TR_J_gene', 'CDS'),
#  ('TR_J_gene', 'TR_J_gene', 'exon'),
#  ('TR_J_gene', 'TR_J_gene', 'transcript'),
#  ('TR_J_pseudogene', 'TR_J_pseudogene', 'exon'),
#  ('TR_J_pseudogene', 'TR_J_pseudogene', 'transcript'),
#  ('TR_V_gene', 'TR_V_gene', 'CDS'),
#  ('TR_V_gene', 'TR_V_gene', 'UTR'),
#  ('TR_V_gene', 'TR_V_gene', 'exon'),
#  ('TR_V_gene', 'TR_V_gene', 'start_codon'),
#  ('TR_V_gene', 'TR_V_gene', 'transcript'),
#  ('TR_V_pseudogene', 'TR_V_pseudogene', 'exon'),
#  ('TR_V_pseudogene', 'TR_V_pseudogene', 'transcript'),
#  ('antisense', 'antisense', 'exon'),
#  ('antisense', 'antisense', 'transcript'),
#  ('antisense', 'processed_transcript', 'exon'),
#  ('antisense', 'processed_transcript', 'transcript'),
#  ('antisense', 'protein_coding', 'exon'),
#  ('antisense', 'protein_coding', 'transcript'),
#  ('bidirectional_promoter_lncRNA', 'bidirectional_promoter_lncRNA', 'exon'),
#  ('bidirectional_promoter_lncRNA',
#   'bidirectional_promoter_lncRNA',
#   'transcript'),
#  ('bidirectional_promoter_lncRNA', 'processed_transcript', 'exon'),
#  ('bidirectional_promoter_lncRNA', 'processed_transcript', 'transcript'),
#  ('lincRNA', 'lincRNA', 'exon'),
#  ('lincRNA', 'lincRNA', 'transcript'),
#  ('lincRNA', 'processed_transcript', 'exon'),
#  ('lincRNA', 'processed_transcript', 'transcript'),
#  ('macro_lncRNA', 'macro_lncRNA', 'exon'),
#  ('macro_lncRNA', 'macro_lncRNA', 'transcript'),
#  ('miRNA', 'lincRNA', 'exon'),
#  ('miRNA', 'lincRNA', 'transcript'),
#  ('miRNA', 'miRNA', 'exon'),
#  ('miRNA', 'miRNA', 'transcript'),
#  ('misc_RNA', 'antisense', 'exon'),
#  ('misc_RNA', 'antisense', 'transcript'),
#  ('misc_RNA', 'lincRNA', 'exon'),
#  ('misc_RNA', 'lincRNA', 'transcript'),
#  ('misc_RNA', 'misc_RNA', 'exon'),
#  ('misc_RNA', 'misc_RNA', 'transcript'),
#  ('misc_RNA', 'processed_transcript', 'exon'),
#  ('misc_RNA', 'processed_transcript', 'transcript'),
#  ('misc_RNA', 'protein_coding', 'exon'),
#  ('misc_RNA', 'protein_coding', 'transcript'),
#  ('misc_RNA', 'sense_overlapping', 'exon'),
#  ('misc_RNA', 'sense_overlapping', 'transcript'),
#  ('non_coding', 'non_coding', 'exon'),
#  ('non_coding', 'non_coding', 'transcript'),
#  ('non_stop_decay', 'protein_coding', 'CDS'),
#  ('non_stop_decay', 'protein_coding', 'Selenocysteine'),
#  ('non_stop_decay', 'protein_coding', 'UTR'),
#  ('non_stop_decay', 'protein_coding', 'exon'),
#  ('non_stop_decay', 'protein_coding', 'start_codon'),
#  ('non_stop_decay', 'protein_coding', 'stop_codon'),
#  ('non_stop_decay', 'protein_coding', 'transcript'),
#  ('nonsense_mediated_decay', 'polymorphic_pseudogene', 'CDS'),
#  ('nonsense_mediated_decay', 'polymorphic_pseudogene', 'UTR'),
#  ('nonsense_mediated_decay', 'polymorphic_pseudogene', 'exon'),
#  ('nonsense_mediated_decay', 'polymorphic_pseudogene', 'start_codon'),
#  ('nonsense_mediated_decay', 'polymorphic_pseudogene', 'stop_codon'),
#  ('nonsense_mediated_decay', 'polymorphic_pseudogene', 'transcript'),
#  ('nonsense_mediated_decay', 'protein_coding', 'CDS'),
#  ('nonsense_mediated_decay', 'protein_coding', 'Selenocysteine'),
#  ('nonsense_mediated_decay', 'protein_coding', 'UTR'),
#  ('nonsense_mediated_decay', 'protein_coding', 'exon'),
#  ('nonsense_mediated_decay', 'protein_coding', 'start_codon'),
#  ('nonsense_mediated_decay', 'protein_coding', 'stop_codon'),
#  ('nonsense_mediated_decay', 'protein_coding', 'transcript'),
#  ('polymorphic_pseudogene', 'polymorphic_pseudogene', 'CDS'),
#  ('polymorphic_pseudogene', 'polymorphic_pseudogene', 'UTR'),
#  ('polymorphic_pseudogene', 'polymorphic_pseudogene', 'exon'),
#  ('polymorphic_pseudogene', 'polymorphic_pseudogene', 'start_codon'),
#  ('polymorphic_pseudogene', 'polymorphic_pseudogene', 'stop_codon'),
#  ('polymorphic_pseudogene', 'polymorphic_pseudogene', 'transcript'),
#  ('processed_pseudogene', 'processed_pseudogene', 'exon'),
#  ('processed_pseudogene', 'processed_pseudogene', 'transcript'),
#  ('processed_pseudogene', 'pseudogene', 'exon'),
#  ('processed_pseudogene', 'pseudogene', 'transcript'),
#  ('processed_transcript', 'polymorphic_pseudogene', 'exon'),
#  ('processed_transcript', 'polymorphic_pseudogene', 'transcript'),
#  ('processed_transcript', 'processed_transcript', 'exon'),
#  ('processed_transcript', 'processed_transcript', 'transcript'),
#  ('processed_transcript', 'protein_coding', 'exon'),
#  ('processed_transcript', 'protein_coding', 'transcript'),
#  ('processed_transcript', 'pseudogene', 'exon'),
#  ('processed_transcript', 'pseudogene', 'transcript'),
#  ('processed_transcript', 'transcribed_processed_pseudogene', 'exon'),
#  ('processed_transcript', 'transcribed_processed_pseudogene', 'transcript'),
#  ('processed_transcript', 'transcribed_unitary_pseudogene', 'exon'),
#  ('processed_transcript', 'transcribed_unitary_pseudogene', 'transcript'),
#  ('processed_transcript', 'transcribed_unprocessed_pseudogene', 'exon'),
#  ('processed_transcript', 'transcribed_unprocessed_pseudogene', 'transcript'),
#  ('processed_transcript', 'unitary_pseudogene', 'exon'),
#  ('processed_transcript', 'unitary_pseudogene', 'transcript'),
#  ('protein_coding', 'IG_C_gene', 'CDS'),
#  ('protein_coding', 'IG_C_gene', 'UTR'),
#  ('protein_coding', 'IG_C_gene', 'exon'),
#  ('protein_coding', 'IG_C_gene', 'stop_codon'),
#  ('protein_coding', 'IG_C_gene', 'transcript'),
#  ('protein_coding', 'IG_V_gene', 'CDS'),
#  ('protein_coding', 'IG_V_gene', 'UTR'),
#  ('protein_coding', 'IG_V_gene', 'exon'),
#  ('protein_coding', 'IG_V_gene', 'start_codon'),
#  ('protein_coding', 'IG_V_gene', 'transcript'),
#  ('protein_coding', 'TR_V_gene', 'CDS'),
#  ('protein_coding', 'TR_V_gene', 'exon'),
#  ('protein_coding', 'TR_V_gene', 'transcript'),
#  ('protein_coding', 'polymorphic_pseudogene', 'CDS'),
#  ('protein_coding', 'polymorphic_pseudogene', 'UTR'),
#  ('protein_coding', 'polymorphic_pseudogene', 'exon'),
#  ('protein_coding', 'polymorphic_pseudogene', 'start_codon'),
#  ('protein_coding', 'polymorphic_pseudogene', 'stop_codon'),
#  ('protein_coding', 'polymorphic_pseudogene', 'transcript'),
#  ('protein_coding', 'protein_coding', 'CDS'),
#  ('protein_coding', 'protein_coding', 'Selenocysteine'),
#  ('protein_coding', 'protein_coding', 'UTR'),
#  ('protein_coding', 'protein_coding', 'exon'),
#  ('protein_coding', 'protein_coding', 'start_codon'),
#  ('protein_coding', 'protein_coding', 'stop_codon'),
#  ('protein_coding', 'protein_coding', 'transcript'),
#  ('pseudogene', 'TEC', 'exon'),
#  ('pseudogene', 'TEC', 'transcript'),
#  ('pseudogene', 'antisense', 'exon'),
#  ('pseudogene', 'antisense', 'transcript'),
#  ('pseudogene', 'lincRNA', 'exon'),
#  ('pseudogene', 'lincRNA', 'transcript'),
#  ('pseudogene', 'pseudogene', 'exon'),
#  ('pseudogene', 'pseudogene', 'transcript'),
#  ('pseudogene', 'sense_intronic', 'exon'),
#  ('pseudogene', 'sense_intronic', 'transcript'),
#  ('pseudogene', 'sense_overlapping', 'exon'),
#  ('pseudogene', 'sense_overlapping', 'transcript'),
#  ('rRNA', 'rRNA', 'exon'),
#  ('rRNA', 'rRNA', 'transcript'),
#  ('retained_intron', 'antisense', 'exon'),
#  ('retained_intron', 'antisense', 'transcript'),
#  ('retained_intron', 'lincRNA', 'exon'),
#  ('retained_intron', 'lincRNA', 'transcript'),
#  ('retained_intron', 'polymorphic_pseudogene', 'exon'),
#  ('retained_intron', 'polymorphic_pseudogene', 'transcript'),
#  ('retained_intron', 'processed_transcript', 'exon'),
#  ('retained_intron', 'processed_transcript', 'transcript'),
#  ('retained_intron', 'protein_coding', 'exon'),
#  ('retained_intron', 'protein_coding', 'transcript'),
#  ('retained_intron', 'pseudogene', 'exon'),
#  ('retained_intron', 'pseudogene', 'transcript'),
#  ('retained_intron', 'sense_intronic', 'exon'),
#  ('retained_intron', 'sense_intronic', 'transcript'),
#  ('retained_intron', 'transcribed_processed_pseudogene', 'exon'),
#  ('retained_intron', 'transcribed_processed_pseudogene', 'transcript'),
#  ('retained_intron', 'transcribed_unitary_pseudogene', 'exon'),
#  ('retained_intron', 'transcribed_unitary_pseudogene', 'transcript'),
#  ('retained_intron', 'transcribed_unprocessed_pseudogene', 'exon'),
#  ('retained_intron', 'transcribed_unprocessed_pseudogene', 'transcript'),
#  ('scRNA', 'scRNA', 'exon'),
#  ('scRNA', 'scRNA', 'transcript'),
#  ('sense_intronic', 'processed_transcript', 'exon'),
#  ('sense_intronic', 'processed_transcript', 'transcript'),
#  ('sense_intronic', 'sense_intronic', 'exon'),
#  ('sense_intronic', 'sense_intronic', 'transcript'),
#  ('sense_overlapping', 'processed_transcript', 'exon'),
#  ('sense_overlapping', 'processed_transcript', 'transcript'),
#  ('sense_overlapping', 'sense_overlapping', 'exon'),
#  ('sense_overlapping', 'sense_overlapping', 'transcript'),
#  ('snRNA', 'snRNA', 'exon'),
#  ('snRNA', 'snRNA', 'transcript'),
#  ('snoRNA', 'lincRNA', 'exon'),
#  ('snoRNA', 'lincRNA', 'transcript'),
#  ('snoRNA', 'snoRNA', 'exon'),
#  ('snoRNA', 'snoRNA', 'transcript'),
#  ('transcribed_processed_pseudogene', 'pseudogene', 'exon'),
#  ('transcribed_processed_pseudogene', 'pseudogene', 'transcript'),
#  ('transcribed_processed_pseudogene',
#   'transcribed_processed_pseudogene',
#   'exon'),
#  ('transcribed_processed_pseudogene',
#   'transcribed_processed_pseudogene',
#   'transcript'),
#  ('transcribed_unitary_pseudogene', 'protein_coding', 'exon'),
#  ('transcribed_unitary_pseudogene', 'protein_coding', 'transcript'),
#  ('transcribed_unitary_pseudogene', 'transcribed_unitary_pseudogene', 'exon'),
#  ('transcribed_unitary_pseudogene',
#   'transcribed_unitary_pseudogene',
#   'transcript'),
#  ('transcribed_unprocessed_pseudogene', 'protein_coding', 'exon'),
#  ('transcribed_unprocessed_pseudogene', 'protein_coding', 'transcript'),
#  ('transcribed_unprocessed_pseudogene', 'pseudogene', 'exon'),
#  ('transcribed_unprocessed_pseudogene', 'pseudogene', 'transcript'),
#  ('transcribed_unprocessed_pseudogene',
#   'transcribed_unprocessed_pseudogene',
#   'exon'),
#  ('transcribed_unprocessed_pseudogene',
#   'transcribed_unprocessed_pseudogene',
#   'transcript'),
#  ('unitary_pseudogene', 'pseudogene', 'exon'),
#  ('unitary_pseudogene', 'pseudogene', 'transcript'),
#  ('unitary_pseudogene', 'unitary_pseudogene', 'exon'),
#  ('unitary_pseudogene', 'unitary_pseudogene', 'transcript'),
#  ('unprocessed_pseudogene', 'pseudogene', 'exon'),
#  ('unprocessed_pseudogene', 'pseudogene', 'transcript'),
#  ('unprocessed_pseudogene', 'unprocessed_pseudogene', 'exon'),
#  ('unprocessed_pseudogene', 'unprocessed_pseudogene', 'transcript'),
#  ('vaultRNA', 'vaultRNA', 'exon'),
#  ('vaultRNA', 'vaultRNA', 'transcript')}
